# %% [markdown]
# ## Mean Term Frequency Inverse Document Frequency Feature
#
# [TF-IDF Site](http://www.tfidf.com/)
#
# Tf-idf stands for term frequency-inverse document frequency, and the tf-idf weight is a weight often used in information retrieval and text mining. This weight is a statistical measure used to evaluate how important a word is to a document in a collection or corpus. The importance increases proportionally to the number of times a word appears in the document but is offset by the frequency of the word in the corpus.
#
# The tf-idf weight is composed by two terms:
#
# #### 1. Term Frequency (TF)
# This measures how frequently a term occurs in a document. It is the number of times a word appears in a document, divided by the total number of words in that document.
# ```
# TF(t) = (Number of times term t appears in a document) / (Total number of terms in the document)
# ```
#
# #### 2.  Inverse Document Frequency (IDF)
# This measures how important a term is. It is computed as the logarithm of the number of the documents in the corpus divided by the number of documents where the specific term appears. Certain terms, such as "is", "of", and "that", may appear a lot of times but have little importance. Thus we need to weigh down the frequent terms while scale up the rare ones, by computing the following:
# ```
# IDF(t) = log_e(Total number of documents / Number of documents with term t in it)
# ```
#
# ### Example
#
# Consider a document containing 100 words wherein the word cat appears 3 times. The term frequency (i.e., tf) for cat is then (3 / 100) = 0.03. Now, assume we have 10 million documents and the word cat appears in one thousand of these. Then, the inverse document frequency (i.e., idf) is calculated as log(10,000,000 / 1,000) = 4. Thus, the Tf-idf weight is the product of these quantities: 0.03 * 4 = 0.12.
#
# In the current use case of conversations, conversations are partitioned by day. Each day conversation is therefore considered a single document. Thus, if we have 27 days of chat messages, we have 27 documents.

# %%
import gzip
import json
import math
import nltk
import string

from os.path import join

# %%
PUNCTUATION_SET = set(string.punctuation)
CHAT_LOG_FILE = "gnue_irc_chat_logs.tsv.gz"
SUMMARIZED_CHAT_LOG_FILE = "summarized_chat_logs.csv.gz"
CHAT_DATE_PARTITIONS_FILE = 'chat_date_partitions.csv'
SUMMARIZED_CHAT_DATE_PARTITIONS_FILE = 'summarized_chat_date_partitions.csv'
OUTPUT_DIR = "feature_outputs"
WORD_FREQUENCIES = {}
WORD_COUNT = 0

# %%
def strip_leading_and_trailing_punctuation(word):
    return word.strip(string.punctuation)

# %%
def update_word_frequency_and_count(word, current_document_number):
    if word not in WORD_FREQUENCIES:
        WORD_FREQUENCIES[word] = {
            "total_frequency": 1,
            "containing_document_count": 1,
            "last_containing_document": current_document_number
            }
    else:
        WORD_FREQUENCIES[word]["total_frequency"] += 1
        if WORD_FREQUENCIES[word]["last_containing_document"] < current_document_number:
            WORD_FREQUENCIES[word]["containing_document_count"] += 1
            WORD_FREQUENCIES[word]["last_containing_document"] = current_document_number
    global WORD_COUNT 
    WORD_COUNT += 1

# %%
def all_chars_in_word_are_punctuation(word):
    return all(char in PUNCTUATION_SET for char in word)

# %%
def pre_process_words_in_sentence(sentence, current_document_number):
    if not sentence:
        print("No words here")
    if type(sentence) is not str:
        try:
            sentence = sentence.decode('utf-8')
        except Exception:
            raise ValueError("Input must be a String or ByteString")
        
    for word in sentence.split():
        if not all_chars_in_word_are_punctuation(word):
            word = strip_leading_and_trailing_punctuation(word)
            if ',' in word:
                words = word.split(',')
                for word in words:
                    if not all_chars_in_word_are_punctuation(word):
                        update_word_frequency_and_count(word, current_document_number)
            else:
                update_word_frequency_and_count(word, current_document_number)

# %%
pre_process_words_in_sentence(b"Hello,there. Ju,.,.'',,,,,,,,,st checking-in.", 2)

# %%
WORD_FREQUENCIES
# Out:
# {'Hello': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2},
#  'there': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2},
#  'Ju': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2},
#  'st': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2},
#  'checking-in': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2}}

# %%
WORD_COUNT
# Out:
# 5

# %%
def generate_document_word_frequencies(date_partitions_file, input_file, output_directory, output_file):
    data_output_file = join(output_directory, output_file)
    with open(date_partitions_file, 'r') as chat_partitions, gzip.open(input_file, 'r') as chat_file, open(data_output_file, 'w') as out_file:
        csv_row = chat_partitions.readline()
        total_chats_in_document = int(csv_row.rstrip().split(',')[2])
        document_number = 1
        chat_line_count = 0
        total_chat_lines_in_all_documents = 0
        for i, chat_line in enumerate(chat_file):
             # Get only the count
            pre_process_words_in_sentence(chat_line, document_number)
            chat_line_count += 1
            if chat_line_count >= total_chats_in_document:
                total_chat_lines_in_all_documents += chat_line_count
                csv_row = chat_partitions.readline()
                if not csv_row:
                    print(i)
                    print(total_chat_lines_in_all_documents)
                    assert i+1 == total_chat_lines_in_all_documents
                    assert chat_line_count == total_chats_in_document
                    break
                    
                # reset the chat_line_count
                chat_line_count = 0
                document_number += 1
                total_chats_in_document = int(csv_row.rstrip().split(',')[2])
        global WORD_COUNT
        frequency_data = {
            "total_word_count": WORD_COUNT,
            "word_frequencies": WORD_FREQUENCIES
        }
        print(document_number)
        print(chat_line_count)
        json.dump(frequency_data, out_file)

# %%
# BE SURE TO RESET WORD_COUNT and WORD_FREQUENCIES BEFORE RUNNING THIS!
WORD_COUNT = 0
WORD_FREQUENCIES = {}
generate_document_word_frequencies(CHAT_DATE_PARTITIONS_FILE, CHAT_LOG_FILE, OUTPUT_DIR + "/all_chat_outputs", "chat_word_frequencies.json")
# generate_document_word_frequencies(SUMMARIZED_CHAT_DATE_PARTITIONS_FILE, SUMMARIZED_CHAT_LOG_FILE, OUTPUT_DIR, "summarized_doc_word_frequencies.json")
# Out:
# 659164
# 659165
# 1784
# 337

# %%
WORD_FREQUENCIES
# Out:
# {'DEREK': {'total_frequency': 7,
#   'containing_document_count': 7,
#   'last_containing_document': 1458},
#  'cvs': {'total_frequency': 3716,
#   'containing_document_count': 720,
#   'last_containing_document': 1784},
#  'diff': {'total_frequency': 347,
#   'containing_document_count': 202,
#   'last_containing_document': 1777},
#  'will': {'total_frequency': 13511,
#   'containing_document_count': 1407,
#   'last_containing_document': 1784},
#  'give': {'total_frequency': 2396,
#   'containing_document_count': 884,
#   'last_containing_document': 1781},
#  'you': {'total_frequency': 68619,
#   'containing_document_count': 1612,
#   'last_containing_document': 1784},
#  'the': {'total_frequency': 134568,
#   'containing_document_count': 1650,
#   'last_containing_document': 1784},
#  'diffs': {'total_frequency': 58,
#   'containing_document_count': 47,
#   'last_containing_document': 1764},
#  'status': {'total_frequency': 518,
#   'containing_document_count': 326,
#   'last_containing_document': 1784},
#  'tell': {'total_frequency': 2247,
#   'containing_document_count': 860,
#   'last_containing_document': 1781},
#  'stats': {'total_frequency': 56,
#   'containing_document_count': 45,
#   'last_containing_document': 1640},
#  'on': {'total_frequency': 29805,
#   'containing_document_count': 1560,
#   'last_containing_document': 1784},
#  'each': {'total_frequency': 1289,
#   'containing_document_count': 629,
#   'last_containing_document': 1784},
#  'file': {'total_frequency': 5190,
#   'containing_document_count': 1025,
#   'last_containing_document': 1784},
#  'jamest': {'total_frequency': 7901,
#   'containing_document_count': 1086,
#   'last_containing_document': 1784},
#  'hi': {'total_frequency': 9427,
#   'containing_document_count': 1519,
#   'last_containing_document': 1784},
#  'btw': {'total_frequency': 2755,
#   'containing_document_count': 945,
#   'last_containing_document': 1784},
#  'www.gnue.org': {'total_frequency': 27,
#   'containing_document_count': 21,
#   'last_containing_document': 1716},
#  "doesn't": {'total_frequency': 3952,
#   'containing_document_count': 1087,
#   'last_containing_document': 1784},
#  'work': {'total_frequency': 10168,
#   'containing_document_count': 1366,
#   'last_containing_document': 1784},
#  'for': {'total_frequency': 41938,
#   'containing_document_count': 1584,
#   'last_containing_document': 1784},
#  'me': {'total_frequency': 15537,
#   'containing_document_count': 1430,
#   'last_containing_document': 1784},
#  'www.gnuenterprise.org': {'total_frequency': 105,
#   'containing_document_count': 78,
#   'last_containing_document': 1778},
#  'does': {'total_frequency': 6639,
#   'containing_document_count': 1263,
#   'last_containing_document': 1784},
#  'different': {'total_frequency': 2324,
#   'containing_document_count': 833,
#   'last_containing_document': 1781},
#  'ip': {'total_frequency': 158,
#   'containing_document_count': 99,
#   'last_containing_document': 1779},
#  'addresses': {'total_frequency': 186,
#   'containing_document_count': 117,
#   'last_containing_document': 1781},
#  'have': {'total_frequency': 35797,
#   'containing_document_count': 1562,
#   'last_containing_document': 1784},
#  'some': {'total_frequency': 11892,
#   'containing_document_count': 1420,
#   'last_containing_document': 1784},
#  'time': {'total_frequency': 8506,
#   'containing_document_count': 1327,
#   'last_containing_document': 1784},
#  'a': {'total_frequency': 89222,
#   'containing_document_count': 1636,
#   'last_containing_document': 1784},
#  'little': {'total_frequency': 2022,
#   'containing_document_count': 830,
#   'last_containing_document': 1783},
#  'gnue.org': {'total_frequency': 127,
#   'containing_document_count': 79,
#   'last_containing_document': 1768},
#  'is': {'total_frequency': 67701,
#   'containing_document_count': 1620,
#   'last_containing_document': 1784},
#  'machine': {'total_frequency': 1551,
#   'containing_document_count': 606,
#   'last_containing_document': 1781},
#  'needs': {'total_frequency': 1827,
#   'containing_document_count': 767,
#   'last_containing_document': 1784},
#  'to': {'total_frequency': 111225,
#   'containing_document_count': 1644,
#   'last_containing_document': 1784},
#  'get': {'total_frequency': 13620,
#   'containing_document_count': 1404,
#   'last_containing_document': 1784},
#  'moved': {'total_frequency': 393,
#   'containing_document_count': 292,
#   'last_containing_document': 1781},
#  'same': {'total_frequency': 4321,
#   'containing_document_count': 1136,
#   'last_containing_document': 1784},
#  'one': {'total_frequency': 12621,
#   'containing_document_count': 1380,
#   'last_containing_document': 1784},
#  'as': {'total_frequency': 21354,
#   'containing_document_count': 1463,
#   'last_containing_document': 1784},
#  'gnuenterprise': {'total_frequency': 425,
#   'containing_document_count': 293,
#   'last_containing_document': 1779},
#  'org': {'total_frequency': 102,
#   'containing_document_count': 73,
#   'last_containing_document': 1759},
#  'did': {'total_frequency': 6423,
#   'containing_document_count': 1236,
#   'last_containing_document': 1781},
#  'look': {'total_frequency': 4279,
#   'containing_document_count': 1135,
#   'last_containing_document': 1784},
#  'at': {'total_frequency': 16416,
#   'containing_document_count': 1472,
#   'last_containing_document': 1784},
#  'how': {'total_frequency': 10484,
#   'containing_document_count': 1401,
#   'last_containing_document': 1784},
#  'i': {'total_frequency': 61528,
#   'containing_document_count': 1570,
#   'last_containing_document': 1784},
#  'loaded': {'total_frequency': 322,
#   'containing_document_count': 229,
#   'last_containing_document': 1779},
#  'widgets': {'total_frequency': 414,
#   'containing_document_count': 183,
#   'last_containing_document': 1781},
#  'in': {'total_frequency': 55373,
#   'containing_document_count': 1596,
#   'last_containing_document': 1784},
#  'code': {'total_frequency': 5251,
#   'containing_document_count': 1068,
#   'last_containing_document': 1784},
#  'sended': {'total_frequency': 42,
#   'containing_document_count': 35,
#   'last_containing_document': 1769},
#  'ago': {'total_frequency': 1512,
#   'containing_document_count': 761,
#   'last_containing_document': 1781},
#  'yes': {'total_frequency': 10136,
#   'containing_document_count': 1358,
#   'last_containing_document': 1784},
#  'real': {'total_frequency': 1941,
#   'containing_document_count': 791,
#   'last_containing_document': 1784},
#  'questoin': {'total_frequency': 14,
#   'containing_document_count': 13,
#   'last_containing_document': 1770},
#  'do': {'total_frequency': 23049,
#   'containing_document_count': 1490,
#   'last_containing_document': 1784},
#  'I': {'total_frequency': 63980,
#   'containing_document_count': 1578,
#   'last_containing_document': 1784},
#  'remember': {'total_frequency': 1281,
#   'containing_document_count': 690,
#   'last_containing_document': 1784},
#  'much': {'total_frequency': 5220,
#   'containing_document_count': 1160,
#   'last_containing_document': 1784},
#  'about': {'total_frequency': 12669,
#   'containing_document_count': 1402,
#   'last_containing_document': 1784},
#  'them': {'total_frequency': 7100,
#   'containing_document_count': 1198,
#   'last_containing_document': 1784},
#  'grin': {'total_frequency': 29,
#   'containing_document_count': 27,
#   'last_containing_document': 1736},
#  'ok': {'total_frequency': 13935,
#   'containing_document_count': 1428,
#   'last_containing_document': 1784},
#  'which': {'total_frequency': 7260,
#   'containing_document_count': 1260,
#   'last_containing_document': 1784},
#  'answer': {'total_frequency': 997,
#   'containing_document_count': 562,
#   'last_containing_document': 1784},
#  'no': {'total_frequency': 14779,
#   'containing_document_count': 1463,
#   'last_containing_document': 1784},
#  'IIRC': {'total_frequency': 994,
#   'containing_document_count': 554,
#   'last_containing_document': 1784},
#  'they': {'total_frequency': 12730,
#   'containing_document_count': 1269,
#   'last_containing_document': 1784},
#  'differently': {'total_frequency': 114,
#   'containing_document_count': 105,
#   'last_containing_document': 1778},
#  'TODO': {'total_frequency': 216,
#   'containing_document_count': 146,
#   'last_containing_document': 1777},
#  'found': {'total_frequency': 2009,
#   'containing_document_count': 892,
#   'last_containing_document': 1784},
#  'that': {'total_frequency': 57097,
#   'containing_document_count': 1565,
#   'last_containing_document': 1784},
#  'event': {'total_frequency': 544,
#   'containing_document_count': 239,
#   'last_containing_document': 1780},
#  'system': {'total_frequency': 3479,
#   'containing_document_count': 910,
#   'last_containing_document': 1784},
#  'not': {'total_frequency': 29410,
#   'containing_document_count': 1541,
#   'last_containing_document': 1784},
#  'flexible': {'total_frequency': 108,
#   'containing_document_count': 95,
#   'last_containing_document': 1770},
#  'enough': {'total_frequency': 1828,
#   'containing_document_count': 801,
#   'last_containing_document': 1781},
#  'so': {'total_frequency': 22748,
#   'containing_document_count': 1482,
#   'last_containing_document': 1784},
#  'there': {'total_frequency': 14029,
#   'containing_document_count': 1473,
#   'last_containing_document': 1784},
#  'were': {'total_frequency': 3573,
#   'containing_document_count': 976,
#   'last_containing_document': 1781},
#  'problems': {'total_frequency': 1241,
#   'containing_document_count': 649,
#   'last_containing_document': 1784},
#  'what': {'total_frequency': 20601,
#   'containing_document_count': 1474,
#   'last_containing_document': 1784},
#  'kind': {'total_frequency': 1357,
#   'containing_document_count': 701,
#   'last_containing_document': 1781},
#  'of': {'total_frequency': 47061,
#   'containing_document_count': 1583,
#   'last_containing_document': 1784},
#  'changes': {'total_frequency': 1402,
#   'containing_document_count': 648,
#   'last_containing_document': 1781},
#  'are': {'total_frequency': 23073,
#   'containing_document_count': 1512,
#   'last_containing_document': 1784},
#  'thinking': {'total_frequency': 1673,
#   'containing_document_count': 746,
#   'last_containing_document': 1784},
#  'let': {'total_frequency': 2359,
#   'containing_document_count': 876,
#   'last_containing_document': 1784},
#  'reread': {'total_frequency': 31,
#   'containing_document_count': 29,
#   'last_containing_document': 1757},
#  'todo': {'total_frequency': 174,
#   'containing_document_count': 133,
#   'last_containing_document': 1780},
#  "I'm": {'total_frequency': 8208,
#   'containing_document_count': 1269,
#   'last_containing_document': 1784},
#  '100': {'total_frequency': 750,
#   'containing_document_count': 437,
#   'last_containing_document': 1780},
#  'sure': {'total_frequency': 5487,
#   'containing_document_count': 1248,
#   'last_containing_document': 1784},
#  'applies': {'total_frequency': 62,
#   'containing_document_count': 56,
#   'last_containing_document': 1778},
#  'anymore': {'total_frequency': 581,
#   'containing_document_count': 410,
#   'last_containing_document': 1780},
#  'ah': {'total_frequency': 4099,
#   'containing_document_count': 1154,
#   'last_containing_document': 1784},
#  'was': {'total_frequency': 17696,
#   'containing_document_count': 1461,
#   'last_containing_document': 1784},
#  'i18n': {'total_frequency': 271,
#   'containing_document_count': 118,
#   'last_containing_document': 1769},
#  'but': {'total_frequency': 29891,
#   'containing_document_count': 1534,
#   'last_containing_document': 1784},
#  'requires': {'total_frequency': 319,
#   'containing_document_count': 240,
#   'last_containing_document': 1784},
#  'python2': {'total_frequency': 80,
#   'containing_document_count': 37,
#   'last_containing_document': 1781},
#  'think': {'total_frequency': 15666,
#   'containing_document_count': 1428,
#   'last_containing_document': 1784},
#  'python1.52': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'still': {'total_frequency': 5650,
#   'containing_document_count': 1244,
#   'last_containing_document': 1781},
#  'standard': {'total_frequency': 816,
#   'containing_document_count': 436,
#   'last_containing_document': 1780},
#  "we're": {'total_frequency': 1101,
#   'containing_document_count': 573,
#   'last_containing_document': 1784},
#  'moving': {'total_frequency': 473,
#   'containing_document_count': 321,
#   'last_containing_document': 1771},
#  '2.0.1': {'total_frequency': 12,
#   'containing_document_count': 11,
#   'last_containing_document': 1543},
#  "we've": {'total_frequency': 483,
#   'containing_document_count': 338,
#   'last_containing_document': 1781},
#  'got': {'total_frequency': 5243,
#   'containing_document_count': 1195,
#   'last_containing_document': 1784},
#  '1.5.2': {'total_frequency': 162,
#   'containing_document_count': 70,
#   'last_containing_document': 1779},
#  'compatibility': {'total_frequency': 96,
#   'containing_document_count': 73,
#   'last_containing_document': 1728},
#  'now': {'total_frequency': 12345,
#   'containing_document_count': 1428,
#   'last_containing_document': 1784},
#  '2.x': {'total_frequency': 115,
#   'containing_document_count': 61,
#   'last_containing_document': 1759},
#  'allow': {'total_frequency': 514,
#   'containing_document_count': 359,
#   'last_containing_document': 1784},
#  'us': {'total_frequency': 2251,
#   'containing_document_count': 791,
#   'last_containing_document': 1784},
#  'remove': {'total_frequency': 770,
#   'containing_document_count': 419,
#   'last_containing_document': 1782},
#  'workarrounds': {'total_frequency': 2,
#   'containing_document_count': 2,
#   'last_containing_document': 1256},
#  'it': {'total_frequency': 71655,
#   'containing_document_count': 1603,
#   'last_containing_document': 1784},
#  'possible': {'total_frequency': 1378,
#   'containing_document_count': 686,
#   'last_containing_document': 1780},
#  'add': {'total_frequency': 2388,
#   'containing_document_count': 865,
#   'last_containing_document': 1783},
#  'specific': {'total_frequency': 709,
#   'containing_document_count': 433,
#   'last_containing_document': 1781},
#  'stuff': {'total_frequency': 5797,
#   'containing_document_count': 1143,
#   'last_containing_document': 1784},
#  'already': {'total_frequency': 2481,
#   'containing_document_count': 955,
#   'last_containing_document': 1784},
#  'maybe': {'total_frequency': 3880,
#   'containing_document_count': 1097,
#   'last_containing_document': 1784},
#  'comments': {'total_frequency': 442,
#   'containing_document_count': 281,
#   'last_containing_document': 1777},
#  'website': {'total_frequency': 703,
#   'containing_document_count': 412,
#   'last_containing_document': 1781},
#  'would': {'total_frequency': 14658,
#   'containing_document_count': 1413,
#   'last_containing_document': 1784},
#  'be': {'total_frequency': 30517,
#   'containing_document_count': 1526,
#   'last_containing_document': 1784},
#  'good': {'total_frequency': 9815,
#   'containing_document_count': 1570,
#   'last_containing_document': 1784},
#  'required': {'total_frequency': 378,
#   'containing_document_count': 253,
#   'last_containing_document': 1779},
#  'python': {'total_frequency': 5603,
#   'containing_document_count': 1014,
#   'last_containing_document': 1784},
#  'version': {'total_frequency': 2735,
#   'containing_document_count': 878,
#   'last_containing_document': 1783},
#  'modules': {'total_frequency': 753,
#   'containing_document_count': 363,
#   'last_containing_document': 1772},
#  'coding': {'total_frequency': 459,
#   'containing_document_count': 289,
#   'last_containing_document': 1777},
#  'style': {'total_frequency': 425,
#   'containing_document_count': 256,
#   'last_containing_document': 1781},
#  'we': {'total_frequency': 21592,
#   'containing_document_count': 1406,
#   'last_containing_document': 1784},
#  'could': {'total_frequency': 7934,
#   'containing_document_count': 1288,
#   'last_containing_document': 1784},
#  'site': {'total_frequency': 1301,
#   'containing_document_count': 578,
#   'last_containing_document': 1781},
#  'pretty': {'total_frequency': 2178,
#   'containing_document_count': 829,
#   'last_containing_document': 1784},
#  'all': {'total_frequency': 17801,
#   'containing_document_count': 1608,
#   'last_containing_document': 1784},
#  'docs': {'total_frequency': 1366,
#   'containing_document_count': 517,
#   'last_containing_document': 1784},
#  'then': {'total_frequency': 11230,
#   'containing_document_count': 1355,
#   'last_containing_document': 1784},
#  "i'll": {'total_frequency': 1506,
#   'containing_document_count': 695,
#   'last_containing_document': 1781},
#  'continue': {'total_frequency': 254,
#   'containing_document_count': 199,
#   'last_containing_document': 1766},
#  'and': {'total_frequency': 64097,
#   'containing_document_count': 1600,
#   'last_containing_document': 1784},
#  'send': {'total_frequency': 1351,
#   'containing_document_count': 611,
#   'last_containing_document': 1784},
#  'soon': {'total_frequency': 1212,
#   'containing_document_count': 653,
#   'last_containing_document': 1781},
#  'too': {'total_frequency': 7819,
#   'containing_document_count': 1312,
#   'last_containing_document': 1784},
#  'coo': {'total_frequency': 8,
#   'containing_document_count': 8,
#   'last_containing_document': 1717},
#  'l': {'total_frequency': 199,
#   'containing_document_count': 132,
#   'last_containing_document': 1757},
#  'cu': {'total_frequency': 229,
#   'containing_document_count': 192,
#   'last_containing_document': 1778},
#  'l8r': {'total_frequency': 513,
#   'containing_document_count': 357,
#   'last_containing_document': 1784},
#  'hey': {'total_frequency': 2955,
#   'containing_document_count': 888,
#   'last_containing_document': 1784},
#  'howdy': {'total_frequency': 573,
#   'containing_document_count': 401,
#   'last_containing_document': 1784},
#  'yello': {'total_frequency': 3,
#   'containing_document_count': 3,
#   'last_containing_document': 625},
#  'gnuebot': {'total_frequency': 83,
#   'containing_document_count': 51,
#   'last_containing_document': 1724},
#  'here': {'total_frequency': 7919,
#   'containing_document_count': 1350,
#   'last_containing_document': 1784},
#  'uswest': {'total_frequency': 2,
#   'containing_document_count': 2,
#   'last_containing_document': 896},
#  'sucks': {'total_frequency': 927,
#   'containing_document_count': 471,
#   'last_containing_document': 1781},
#  'back': {'total_frequency': 4753,
#   'containing_document_count': 1180,
#   'last_containing_document': 1784},
#  'masta': {'total_frequency': 512,
#   'containing_document_count': 245,
#   'last_containing_document': 1784},
#  'hello': {'total_frequency': 2545,
#   'containing_document_count': 1032,
#   'last_containing_document': 1782},
#  'BitchX': {'total_frequency': 17,
#   'containing_document_count': 14,
#   'last_containing_document': 1637},
#  'cool': {'total_frequency': 4126,
#   'containing_document_count': 1066,
#   'last_containing_document': 1784},
#  'um': {'total_frequency': 2127,
#   'containing_document_count': 677,
#   'last_containing_document': 1784},
#  'really': {'total_frequency': 5729,
#   'containing_document_count': 1194,
#   'last_containing_document': 1784},
#  'prefer': {'total_frequency': 518,
#   'containing_document_count': 361,
#   'last_containing_document': 1784},
#  'xchat': {'total_frequency': 261,
#   'containing_document_count': 159,
#   'last_containing_document': 1740},
#  'must': {'total_frequency': 2078,
#   'containing_document_count': 879,
#   'last_containing_document': 1784},
#  'live': {'total_frequency': 743,
#   'containing_document_count': 421,
#   'last_containing_document': 1781},
#  'w': {'total_frequency': 1442,
#   'containing_document_count': 589,
#   'last_containing_document': 1784},
#  'works': {'total_frequency': 3546,
#   'containing_document_count': 1048,
#   'last_containing_document': 1784},
#  'yeah': {'total_frequency': 5873,
#   'containing_document_count': 1152,
#   'last_containing_document': 1784},
#  'guess': {'total_frequency': 2679,
#   'containing_document_count': 940,
#   'last_containing_document': 1784},
#  'sorta': {'total_frequency': 293,
#   'containing_document_count': 214,
#   'last_containing_document': 1784},
#  'mean': {'total_frequency': 3778,
#   'containing_document_count': 1068,
#   'last_containing_document': 1784},
#  'spirited': {'total_frequency': 2,
#   'containing_document_count': 2,
#   'last_containing_document': 831},
#  'actually': {'total_frequency': 3634,
#   'containing_document_count': 1068,
#   'last_containing_document': 1784},
#  'kicks': {'total_frequency': 145,
#   'containing_document_count': 124,
#   'last_containing_document': 1781},
#  'ass': {'total_frequency': 604,
#   'containing_document_count': 349,
#   'last_containing_document': 1784},
#  "there's": {'total_frequency': 2017,
#   'containing_document_count': 846,
#   'last_containing_document': 1784},
#  'command': {'total_frequency': 974,
#   'containing_document_count': 493,
#   'last_containing_document': 1781},
#  'call': {'total_frequency': 2378,
#   'containing_document_count': 849,
#   'last_containing_document': 1784},
#  'fuckem': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'IF': {'total_frequency': 54,
#   'containing_document_count': 43,
#   'last_containing_document': 1767},
#  'dont': {'total_frequency': 4592,
#   'containing_document_count': 882,
#   'last_containing_document': 1784},
#  'any': {'total_frequency': 6361,
#   'containing_document_count': 1319,
#   'last_containing_document': 1784},
#  'messages': {'total_frequency': 558,
#   'containing_document_count': 346,
#   'last_containing_document': 1772},
#  'msg': {'total_frequency': 445,
#   'containing_document_count': 281,
#   'last_containing_document': 1784},
#  'AND': {'total_frequency': 248,
#   'containing_document_count': 146,
#   'last_containing_document': 1770},
#  'only': {'total_frequency': 7743,
#   'containing_document_count': 1307,
#   'last_containing_document': 1784},
#  'talk': {'total_frequency': 1373,
#   'containing_document_count': 631,
#   'last_containing_document': 1781},
#  'channel': {'total_frequency': 920,
#   'containing_document_count': 510,
#   'last_containing_document': 1784},
#  'can': {'total_frequency': 20833,
#   'containing_document_count': 1479,
#   'last_containing_document': 1784},
#  'use': {'total_frequency': 12273,
#   'containing_document_count': 1366,
#   'last_containing_document': 1784},
#  'hidden': {'total_frequency': 126,
#   'containing_document_count': 94,
#   'last_containing_document': 1782},
#  'windows': {'total_frequency': 2373,
#   'containing_document_count': 657,
#   'last_containing_document': 1781},
#  'set': {'total_frequency': 2648,
#   'containing_document_count': 925,
#   'last_containing_document': 1784},
#  'up': {'total_frequency': 9604,
#   'containing_document_count': 1335,
#   'last_containing_document': 1784},
#  'take': {'total_frequency': 2613,
#   'containing_document_count': 916,
#   'last_containing_document': 1784},
#  'msgs': {'total_frequency': 33,
#   'containing_document_count': 31,
#   'last_containing_document': 1729},
#  'separate': {'total_frequency': 518,
#   'containing_document_count': 327,
#   'last_containing_document': 1781},
#  'window': {'total_frequency': 647,
#   'containing_document_count': 363,
#   'last_containing_document': 1781},
#  'things': {'total_frequency': 4593,
#   'containing_document_count': 1095,
#   'last_containing_document': 1784},
#  'by': {'total_frequency': 5953,
#   'containing_document_count': 1229,
#   'last_containing_document': 1784},
#  'its': {'total_frequency': 7848,
#   'containing_document_count': 1026,
#   'last_containing_document': 1784},
#  'channels': {'total_frequency': 135,
#   'containing_document_count': 102,
#   'last_containing_document': 1767},
#  'talking': {'total_frequency': 1507,
#   'containing_document_count': 641,
#   'last_containing_document': 1781},
#  'read': {'total_frequency': 2875,
#   'containing_document_count': 964,
#   'last_containing_document': 1783},
#  'FAQ': {'total_frequency': 107,
#   'containing_document_count': 81,
#   'last_containing_document': 1777},
#  'instead': {'total_frequency': 1670,
#   'containing_document_count': 796,
#   'last_containing_document': 1784},
#  'bouncing': {'total_frequency': 24,
#   'containing_document_count': 17,
#   'last_containing_document': 1653},
#  'tabs': {'total_frequency': 199,
#   'containing_document_count': 110,
#   'last_containing_document': 1784},
#  'BUT': {'total_frequency': 423,
#   'containing_document_count': 248,
#   'last_containing_document': 1783},
#  'cant': {'total_frequency': 1187,
#   'containing_document_count': 516,
#   'last_containing_document': 1781},
#  'figure': {'total_frequency': 656,
#   'containing_document_count': 443,
#   'last_containing_document': 1781},
#  'out': {'total_frequency': 8236,
#   'containing_document_count': 1318,
#   'last_containing_document': 1784},
#  'im': {'total_frequency': 3398,
#   'containing_document_count': 683,
#   'last_containing_document': 1781},
#  'pain': {'total_frequency': 315,
#   'containing_document_count': 229,
#   'last_containing_document': 1781},
#  'bounce': {'total_frequency': 43,
#   'containing_document_count': 38,
#   'last_containing_document': 1746},
#  'among': {'total_frequency': 85,
#   'containing_document_count': 77,
#   'last_containing_document': 1777},
#  'respond': {'total_frequency': 187,
#   'containing_document_count': 155,
#   'last_containing_document': 1771},
#  'or': {'total_frequency': 20130,
#   'containing_document_count': 1481,
#   'last_containing_document': 1784},
#  'if': {'total_frequency': 22718,
#   'containing_document_count': 1481,
#   'last_containing_document': 1784},
#  'several': {'total_frequency': 834,
#   'containing_document_count': 521,
#   'last_containing_document': 1784},
#  'high': {'total_frequency': 429,
#   'containing_document_count': 288,
#   'last_containing_document': 1767},
#  'volume': {'total_frequency': 79,
#   'containing_document_count': 58,
#   'last_containing_document': 1739},
#  'try': {'total_frequency': 5095,
#   'containing_document_count': 1187,
#   'last_containing_document': 1781},
#  'keep': {'total_frequency': 1445,
#   'containing_document_count': 711,
#   'last_containing_document': 1784},
#  'Alt-1': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'Alt-2': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'switched': {'total_frequency': 173,
#   'containing_document_count': 147,
#   'last_containing_document': 1770},
#  'aliases': {'total_frequency': 64,
#   'containing_document_count': 41,
#   'last_containing_document': 1667},
#  'bitchx': {'total_frequency': 59,
#   'containing_document_count': 41,
#   'last_containing_document': 1777},
#  'alias': {'total_frequency': 103,
#   'containing_document_count': 66,
#   'last_containing_document': 1781},
#  'wnc': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'new': {'total_frequency': 5540,
#   'containing_document_count': 1223,
#   'last_containing_document': 1784},
#  'hide': {'total_frequency': 91,
#   'containing_document_count': 77,
#   'last_containing_document': 1763},
#  'swap': {'total_frequency': 74,
#   'containing_document_count': 45,
#   'last_containing_document': 1744},
#  'last': {'total_frequency': 3502,
#   'containing_document_count': 1131,
#   'last_containing_document': 1783},
#  'double': {'total_frequency': 279,
#   'containing_document_count': 183,
#   'last_containing_document': 1784},
#  'split': {'total_frequency': 242,
#   'containing_document_count': 169,
#   'last_containing_document': 1744},
#  '0': {'total_frequency': 1376,
#   'containing_document_count': 483,
#   'last_containing_document': 1784},
#  'wns': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'server': {'total_frequency': 3322,
#   'containing_document_count': 903,
#   'last_containing_document': 1781},
#  'makes': {'total_frequency': 1650,
#   'containing_document_count': 729,
#   'last_containing_document': 1784},
#  'irc': {'total_frequency': 723,
#   'containing_document_count': 422,
#   'last_containing_document': 1784},
#  'servers': {'total_frequency': 435,
#   'containing_document_count': 265,
#   'last_containing_document': 1772},
#  'switch': {'total_frequency': 532,
#   'containing_document_count': 335,
#   'last_containing_document': 1781},
#  'with': {'total_frequency': 24393,
#   'containing_document_count': 1537,
#   'last_containing_document': 1784},
#  'Alt-x': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'tells': {'total_frequency': 265,
#   'containing_document_count': 224,
#   'last_containing_document': 1781},
#  'ones': {'total_frequency': 826,
#   'containing_document_count': 495,
#   'last_containing_document': 1781},
#  'sctivity': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'Act': {'total_frequency': 15,
#   'containing_document_count': 12,
#   'last_containing_document': 1500},
#  '2': {'total_frequency': 3830,
#   'containing_document_count': 1055,
#   'last_containing_document': 1784},
#  '4': {'total_frequency': 1269,
#   'containing_document_count': 607,
#   'last_containing_document': 1781},
#  'dunno': {'total_frequency': 1223,
#   'containing_document_count': 605,
#   'last_containing_document': 1782},
#  'schat': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'easier': {'total_frequency': 743,
#   'containing_document_count': 466,
#   'last_containing_document': 1783},
#  'though': {'total_frequency': 3550,
#   'containing_document_count': 1046,
#   'last_containing_document': 1784},
#  'lot': {'total_frequency': 2314,
#   'containing_document_count': 869,
#   'last_containing_document': 1783},
#  'built': {'total_frequency': 466,
#   'containing_document_count': 326,
#   'last_containing_document': 1781},
#  'er': {'total_frequency': 2636,
#   'containing_document_count': 710,
#   'last_containing_document': 1784},
#  'jcater': {'total_frequency': 10205,
#   'containing_document_count': 1161,
#   'last_containing_document': 1784},
#  'ra3vat': {'total_frequency': 1241,
#   'containing_document_count': 275,
#   'last_containing_document': 1777},
#  'dneighbo': {'total_frequency': 3708,
#   'containing_document_count': 419,
#   'last_containing_document': 1781},
#  'http://slashdot.org/comments.pl?sid=01/08/06/1054257&threshold=-1&commentsort=3&mode=thread&cid=28': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'toyman': {'total_frequency': 44,
#   'containing_document_count': 28,
#   'last_containing_document': 1679},
#  'wassup': {'total_frequency': 203,
#   'containing_document_count': 170,
#   'last_containing_document': 1781},
#  'congrats': {'total_frequency': 92,
#   'containing_document_count': 76,
#   'last_containing_document': 1771},
#  'conversion': {'total_frequency': 229,
#   'containing_document_count': 148,
#   'last_containing_document': 1769},
#  'checked': {'total_frequency': 433,
#   'containing_document_count': 322,
#   'last_containing_document': 1781},
#  'Access': {'total_frequency': 175,
#   'containing_document_count': 103,
#   'last_containing_document': 1769},
#  'Postgres': {'total_frequency': 69,
#   'containing_document_count': 53,
#   'last_containing_document': 1757},
#  'made': {'total_frequency': 1537,
#   'containing_document_count': 755,
#   'last_containing_document': 1784},
#  'tired': {'total_frequency': 256,
#   'containing_document_count': 212,
#   'last_containing_document': 1781},
#  'looking': {'total_frequency': 2077,
#   'containing_document_count': 854,
#   'last_containing_document': 1781},
#  'details': {'total_frequency': 334,
#   'containing_document_count': 240,
#   'last_containing_document': 1781},
#  'nice': {'total_frequency': 2619,
#   'containing_document_count': 945,
#   'last_containing_document': 1784},
#  'link': {'total_frequency': 845,
#   'containing_document_count': 474,
#   'last_containing_document': 1781},
#  'goats': {'total_frequency': 271,
#   'containing_document_count': 159,
#   'last_containing_document': 1776},
#  'am': {'total_frequency': 5518,
#   'containing_document_count': 1136,
#   'last_containing_document': 1784},
#  'suffering': {'total_frequency': 40,
#   'containing_document_count': 35,
#   'last_containing_document': 1776},
#  'utter': {'total_frequency': 27,
#   'containing_document_count': 25,
#   'last_containing_document': 1769},
#  'death': {'total_frequency': 128,
#   'containing_document_count': 96,
#   'last_containing_document': 1683},
#  'another': {'total_frequency': 2858,
#   'containing_document_count': 1006,
#   'last_containing_document': 1781},
#  'consulting': {'total_frequency': 106,
#   'containing_document_count': 76,
#   'last_containing_document': 1768},
#  'gig': {'total_frequency': 50,
#   'containing_document_count': 45,
#   'last_containing_document': 1751},
#  'hope': {'total_frequency': 1175,
#   'containing_document_count': 669,
#   'last_containing_document': 1781},
#  'unbury': {'total_frequency': 2,
#   'containing_document_count': 2,
#   'last_containing_document': 915},
#  'self': {'total_frequency': 378,
#   'containing_document_count': 236,
#   'last_containing_document': 1783},
#  'want': {'total_frequency': 7893,
#   'containing_document_count': 1242,
#   'last_containing_document': 1784},
#  'REALLY': {'total_frequency': 216,
#   'containing_document_count': 161,
#   'last_containing_document': 1781},
#  'dig': {'total_frequency': 200,
#   'containing_document_count': 161,
#   'last_containing_document': 1781},
#  'into': {'total_frequency': 5359,
#   'containing_document_count': 1195,
#   'last_containing_document': 1783},
#  'your': {'total_frequency': 9995,
#   'containing_document_count': 1331,
#   'last_containing_document': 1784},
#  'converted': {'total_frequency': 174,
#   'containing_document_count': 139,
#   'last_containing_document': 1764},
#  "what's": {'total_frequency': 1739,
#   'containing_document_count': 804,
#   'last_containing_document': 1784},
#  'killin': {'total_frequency': 5,
#   'containing_document_count': 5,
#   'last_containing_document': 1096},
#  'thought': {'total_frequency': 2757,
#   'containing_document_count': 1006,
#   'last_containing_document': 1784},
#  'relevant': {'total_frequency': 119,
#   'containing_document_count': 90,
#   'last_containing_document': 1746},
#  'ToyMan': {'total_frequency': 285,
#   'containing_document_count': 125,
#   'last_containing_document': 1783},
#  'client': {'total_frequency': 2182,
#   'containing_document_count': 694,
#   'last_containing_document': 1784},
#  'hospitality': {'total_frequency': 6,
#   'containing_document_count': 3,
#   'last_containing_document': 222},
#  'career': {'total_frequency': 14,
#   'containing_document_count': 13,
#   'last_containing_document': 1152},
#  'services': {'total_frequency': 397,
#   'containing_document_count': 215,
#   'last_containing_document': 1781},
#  'job': {'total_frequency': 962,
#   'containing_document_count': 492,
#   'last_containing_document': 1781},
#  'placement': {'total_frequency': 34,
#   'containing_document_count': 31,
#   'last_containing_document': 1765},
#  'firm': {'total_frequency': 58,
#   'containing_document_count': 48,
#   'last_containing_document': 1781},
#  'hotel': {'total_frequency': 58,
#   'containing_document_count': 39,
#   'last_containing_document': 1717},
#  'industry': {'total_frequency': 113,
#   'containing_document_count': 78,
#   'last_containing_document': 1781},
#  'stinking': {'total_frequency': 55,
#   'containing_document_count': 46,
#   'last_containing_document': 1724},
#  'web': {'total_frequency': 1928,
#   'containing_document_count': 640,
#   'last_containing_document': 1781},
#  'sounds': {'total_frequency': 1142,
#   'containing_document_count': 621,
#   'last_containing_document': 1781},
#  'exciting': {'total_frequency': 49,
#   'containing_document_count': 43,
#   'last_containing_document': 1758},
#  'interesting': {'total_frequency': 1055,
#   'containing_document_count': 593,
#   'last_containing_document': 1781},
#  'gnue': {'total_frequency': 8571,
#   'containing_document_count': 1286,
#   'last_containing_document': 1781},
#  'hard': {'total_frequency': 1513,
#   'containing_document_count': 723,
#   'last_containing_document': 1783},
#  'excited': {'total_frequency': 81,
#   'containing_document_count': 72,
#   'last_containing_document': 1777},
#  'THOUGH': {'total_frequency': 6,
#   'containing_document_count': 6,
#   'last_containing_document': 1056},
#  'ready': {'total_frequency': 956,
#   'containing_document_count': 519,
#   'last_containing_document': 1776},
#  'move': {'total_frequency': 941,
#   'containing_document_count': 537,
#   'last_containing_document': 1780},
#  'billing': {'total_frequency': 56,
#   'containing_document_count': 39,
#   'last_containing_document': 1767},
#  'GNUe': {'total_frequency': 4054,
#   'containing_document_count': 881,
#   'last_containing_document': 1784},
#  'until': {'total_frequency': 1430,
#   'containing_document_count': 693,
#   'last_containing_document': 1784},
#  'release': {'total_frequency': 2847,
#   'containing_document_count': 790,
#   'last_containing_document': 1784},
#  'module': {'total_frequency': 1852,
#   'containing_document_count': 618,
#   'last_containing_document': 1784},
#  'VPN': {'total_frequency': 56,
#   'containing_document_count': 27,
#   'last_containing_document': 1755},
#  'worked': {'total_frequency': 1219,
#   'containing_document_count': 661,
#   'last_containing_document': 1784},
#  'access': {'total_frequency': 1821,
#   'containing_document_count': 684,
#   'last_containing_document': 1781},
#  'Posgtgres': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'remotely': {'total_frequency': 62,
#   'containing_document_count': 52,
#   'last_containing_document': 1779},
#  'well': {'total_frequency': 11695,
#   'containing_document_count': 1360,
#   'last_containing_document': 1784},
#  'arent': {'total_frequency': 233,
#   'containing_document_count': 185,
#   'last_containing_document': 1781},
#  'recruitement': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'doing': {'total_frequency': 3238,
#   'containing_document_count': 1028,
#   'last_containing_document': 1781},
#  'part': {'total_frequency': 2156,
#   'containing_document_count': 830,
#   'last_containing_document': 1781},
#  'HR': {'total_frequency': 80,
#   'containing_document_count': 53,
#   'last_containing_document': 1769},
#  'Modules': {'total_frequency': 9,
#   'containing_document_count': 9,
#   'last_containing_document': 1528},
#  'hmmmm': {'total_frequency': 408,
#   'containing_document_count': 295,
#   'last_containing_document': 1781},
#  'gotta': {'total_frequency': 639,
#   'containing_document_count': 426,
#   'last_containing_document': 1781},
#  'go': {'total_frequency': 5344,
#   'containing_document_count': 1147,
#   'last_containing_document': 1784},
#  'http://www-106.ibm.com/developerworks/linux/library/l-pippy': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'perhaps': {'total_frequency': 609,
#   'containing_document_count': 361,
#   'last_containing_document': 1781},
#  'catalyst': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'palm': {'total_frequency': 68,
#   'containing_document_count': 28,
#   'last_containing_document': 1758},
#  'man': {'total_frequency': 1888,
#   'containing_document_count': 708,
#   'last_containing_document': 1784},
#  'full': {'total_frequency': 714,
#   'containing_document_count': 442,
#   'last_containing_document': 1781},
#  'bastard': {'total_frequency': 110,
#   'containing_document_count': 92,
#   'last_containing_document': 1781},
#  'starving': {'total_frequency': 10,
#   'containing_document_count': 10,
#   'last_containing_document': 1741},
#  'lol': {'total_frequency': 2925,
#   'containing_document_count': 944,
#   'last_containing_document': 1784},
#  'ate': {'total_frequency': 60,
#   'containing_document_count': 53,
#   'last_containing_document': 1781},
#  'hamburgers': {'total_frequency': 5,
#   'containing_document_count': 4,
#   'last_containing_document': 918},
#  'cooked': {'total_frequency': 15,
#   'containing_document_count': 14,
#   'last_containing_document': 1670},
#  'mayo': {'total_frequency': 2,
#   'containing_document_count': 2,
#   'last_containing_document': 1621},
#  'ketchup': {'total_frequency': 7,
#   'containing_document_count': 7,
#   'last_containing_document': 1769},
#  'honey': {'total_frequency': 31,
#   'containing_document_count': 26,
#   'last_containing_document': 1693},
#  'mustard': {'total_frequency': 7,
#   'containing_document_count': 7,
#   'last_containing_document': 1744},
#  'tomatoes': {'total_frequency': 2,
#   'containing_document_count': 2,
#   'last_containing_document': 1486},
#  'course': {'total_frequency': 1841,
#   'containing_document_count': 821,
#   'last_containing_document': 1783},
#  'pepsi': {'total_frequency': 48,
#   'containing_document_count': 23,
#   'last_containing_document': 1758},
#  'cola': {'total_frequency': 9,
#   'containing_document_count': 8,
#   'last_containing_document': 1679},
#  'arghu': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'nickr': {'total_frequency': 1913,
#   'containing_document_count': 345,
#   'last_containing_document': 1783},
#  'my': {'total_frequency': 17867,
#   'containing_document_count': 1454,
#   'last_containing_document': 1784},
#  'might': {'total_frequency': 3876,
#   'containing_document_count': 1082,
#   'last_containing_document': 1784},
#  'around': {'total_frequency': 2441,
#   'containing_document_count': 983,
#   'last_containing_document': 1784},
#  'paying': {'total_frequency': 166,
#   'containing_document_count': 130,
#   'last_containing_document': 1781},
#  'tomorrow': {'total_frequency': 920,
#   'containing_document_count': 562,
#   'last_containing_document': 1781},
#  'know': {'total_frequency': 10609,
#   'containing_document_count': 1387,
#   'last_containing_document': 1784},
#  'feel': {'total_frequency': 898,
#   'containing_document_count': 499,
#   'last_containing_document': 1781},
#  'like': {'total_frequency': 18249,
#   'containing_document_count': 1453,
#   'last_containing_document': 1784},
#  'bum': {'total_frequency': 31,
#   'containing_document_count': 30,
#   'last_containing_document': 1767},
#  'hehe': {'total_frequency': 2623,
#   'containing_document_count': 794,
#   'last_containing_document': 1781},
#  'chillywilly': {'total_frequency': 7329,
#   'containing_document_count': 897,
#   'last_containing_document': 1784},
#  'working': {'total_frequency': 4519,
#   'containing_document_count': 1169,
#   'last_containing_document': 1784},
#  'fit': {'total_frequency': 369,
#   'containing_document_count': 266,
#   'last_containing_document': 1781},
#  'zen': {'total_frequency': 13,
#   'containing_document_count': 9,
#   'last_containing_document': 1745},
#  'existance': {'total_frequency': 31,
#   'containing_document_count': 28,
#   'last_containing_document': 1570},
#  'heh': {'total_frequency': 2784,
#   'containing_document_count': 820,
#   'last_containing_document': 1784},
#  'growling': {'total_frequency': 3,
#   'containing_document_count': 3,
#   'last_containing_document': 1536},
#  'tummy': {'total_frequency': 4,
#   'containing_document_count': 4,
#   'last_containing_document': 1434},
#  'paid': {'total_frequency': 213,
#   'containing_document_count': 154,
#   'last_containing_document': 1781},
#  'very': {'total_frequency': 3731,
#   'containing_document_count': 1071,
#   'last_containing_document': 1783},
#  'often': {'total_frequency': 397,
#   'containing_document_count': 289,
#   'last_containing_document': 1779},
#  "i'm": {'total_frequency': 4327,
#   'containing_document_count': 1109,
#   'last_containing_document': 1783},
#  'student': {'total_frequency': 85,
#   'containing_document_count': 67,
#   'last_containing_document': 1781},
#  'everyone': {'total_frequency': 1022,
#   'containing_document_count': 600,
#   'last_containing_document': 1777},
#  'knows': {'total_frequency': 520,
#   'containing_document_count': 363,
#   'last_containing_document': 1784},
#  'students': {'total_frequency': 71,
#   'containing_document_count': 51,
#   'last_containing_document': 1776},
#  'bums': {'total_frequency': 5,
#   'containing_document_count': 4,
#   'last_containing_document': 1091},
#  'king': {'total_frequency': 44,
#   'containing_document_count': 37,
#   'last_containing_document': 1769},
#  'hail': {'total_frequency': 26,
#   'containing_document_count': 22,
#   'last_containing_document': 1522},
#  'Heh': {'total_frequency': 91,
#   'containing_document_count': 68,
#   'last_containing_document': 1763},
#  'none': {'total_frequency': 380,
#   'containing_document_count': 297,
#   'last_containing_document': 1779},
#  'line': {'total_frequency': 4366,
#   'containing_document_count': 965,
#   'last_containing_document': 1783},
#  'proper': {'total_frequency': 343,
#   'containing_document_count': 266,
#   'last_containing_document': 1781},
#  "didn't": {'total_frequency': 2823,
#   'containing_document_count': 975,
#   'last_containing_document': 1784},
#  'had': {'total_frequency': 5381,
#   'containing_document_count': 1201,
#   'last_containing_document': 1784},
#  'an': {'total_frequency': 12337,
#   'containing_document_count': 1424,
#   'last_containing_document': 1784},
#  'autonomous': {'total_frequency': 3,
#   'containing_document_count': 3,
#   'last_containing_document': 913},
#  'collective': {'total_frequency': 21,
#   'containing_document_count': 19,
#   'last_containing_document': 1594},
#  'monty': {'total_frequency': 11,
#   'containing_document_count': 9,
#   'last_containing_document': 1736},
#  'right': {'total_frequency': 7149,
#   'containing_document_count': 1281,
#   'last_containing_document': 1784},
#  'nod': {'total_frequency': 222,
#   'containing_document_count': 62,
#   'last_containing_document': 1765},
#  "You're": {'total_frequency': 89,
#   'containing_document_count': 84,
#   'last_containing_document': 1779},
#  'fooling': {'total_frequency': 6,
#   'containing_document_count': 6,
#   'last_containing_document': 1744},
#  'yourself': {'total_frequency': 389,
#   'containing_document_count': 295,
#   'last_containing_document': 1781},
#  "We're": {'total_frequency': 63,
#   'containing_document_count': 51,
#   'last_containing_document': 1740},
#  'livin': {'total_frequency': 4,
#   'containing_document_count': 4,
#   'last_containing_document': 1526},
#  'dictatorship': {'total_frequency': 6,
#   'containing_document_count': 6,
#   'last_containing_document': 1359},
#  'instant': {'total_frequency': 31,
#   'containing_document_count': 31,
#   'last_containing_document': 1767},
#  'stuffing': {'total_frequency': 4,
#   'containing_document_count': 4,
#   'last_containing_document': 1422},
#  'turkey': {'total_frequency': 26,
#   'containing_document_count': 17,
#   'last_containing_document': 1781},
#  'burger': {'total_frequency': 18,
#   'containing_document_count': 14,
#   'last_containing_document': 1781},
#  'nuked': {'total_frequency': 7,
#   'containing_document_count': 7,
#   'last_containing_document': 1671},
#  'within': {'total_frequency': 562,
#   'containing_document_count': 385,
#   'last_containing_document': 1781},
#  'inch': {'total_frequency': 23,
#   'containing_document_count': 18,
#   'last_containing_document': 1706},
#  'life': {'total_frequency': 743,
#   'containing_document_count': 444,
#   'last_containing_document': 1784},
#  'meal': {'total_frequency': 17,
#   'containing_document_count': 17,
#   'last_containing_document': 1690},
#  'especially': {'total_frequency': 412,
#   'containing_document_count': 334,
#   'last_containing_document': 1780},
#  'rounded': {'total_frequency': 4,
#   'containing_document_count': 4,
#   'last_containing_document': 1437},
#  'off': {'total_frequency': 2933,
#   'containing_document_count': 998,
#   'last_containing_document': 1784},
#  'jello': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 1},
#  'bake': {'total_frequency': 3,
#   'containing_document_count': 3,
#   'last_containing_document': 837},
#  'cheesecake': {'total_frequency': 7,
#   'containing_document_count': 4,
#   'last_containing_document': 1633},
#  'mmm': {'total_frequency': 188,
#   'containing_document_count': 136,
#   'last_containing_document': 1776},
#  'bachelor': {'total_frequency': 6,
#   'containing_document_count': 5,
#   'last_containing_document': 1360},
#  'chow': {'total_frequency': 5,
#   'containing_document_count': 5,
#   'last_containing_document': 1543},
#  'gf': {'total_frequency': 27,
#   'containing_document_count': 21,
#   'last_containing_document': 1683},
#  'feed': {'total_frequency': 110,
#   'containing_document_count': 89,
#   'last_containing_document': 1779},
#  'tyou': {'total_frequency': 6,
#   'containing_document_count': 6,
#   'last_containing_document': 1247},
#  'generally': {'total_frequency': 427,
#   'containing_document_count': 286,
#   'last_containing_document': 1781},
#  "she's": {'total_frequency': 136,
#   'containing_document_count': 104,
#   'last_containing_document': 1781},
#  'visiting': {'total_frequency': 26,
#   'containing_document_count': 26,
#   'last_containing_document': 1690},
#  'her': {'total_frequency': 531,
#   'containing_document_count': 269,
#   'last_containing_document': 1779},
#  'cats': {'total_frequency': 58,
#   'containing_document_count': 37,
#   'last_containing_document': 1746},
#  'dog': {'total_frequency': 155,
#   'containing_document_count': 103,
# ...
#   'last_containing_document': 2},
#  'understand': {'total_frequency': 1668,
#   'containing_document_count': 737,
#   'last_containing_document': 1784},
#  'jbailey': {'total_frequency': 2058,
#   'containing_document_count': 463,
#   'last_containing_document': 1779},
#  'dcl': {'total_frequency': 1066,
#   'containing_document_count': 339,
#   'last_containing_document': 1781},
#  'debs': {'total_frequency': 610,
#   'containing_document_count': 290,
#   'last_containing_document': 1780},
#  'Is': {'total_frequency': 705,
#   'containing_document_count': 439,
#   'last_containing_document': 1782},
#  'indifferent': {'total_frequency': 11,
#   'containing_document_count': 10,
#   'last_containing_document': 1536},
#  'qs': {'total_frequency': 2,
#   'containing_document_count': 2,
#   'last_containing_document': 1025},
#  'dir': {'total_frequency': 844,
#   'containing_document_count': 416,
#   'last_containing_document': 1779},
#  'pointed': {'total_frequency': 98,
#   'containing_document_count': 83,
#   'last_containing_document': 1741},
#  'him': {'total_frequency': 2402,
#   'containing_document_count': 762,
#   'last_containing_document': 1781},
#  'words': {'total_frequency': 338,
#   'containing_document_count': 247,
#   'last_containing_document': 1781},
#  'wisdom': {'total_frequency': 23,
#   'containing_document_count': 18,
#   'last_containing_document': 1769},
#  'Oh': {'total_frequency': 367,
#   'containing_document_count': 251,
#   'last_containing_document': 1781},
#  'dear': {'total_frequency': 72,
#   'containing_document_count': 67,
#   'last_containing_document': 1769},
#  'always': {'total_frequency': 1928,
#   'containing_document_count': 838,
#   'last_containing_document': 1784},
#  'stick': {'total_frequency': 296,
#   'containing_document_count': 231,
#   'last_containing_document': 1778},
#  '80': {'total_frequency': 197,
#   'containing_document_count': 127,
#   'last_containing_document': 1747},
#  'cols': {'total_frequency': 6,
#   'containing_document_count': 5,
#   'last_containing_document': 1489},
#  'wide': {'total_frequency': 120,
#   'containing_document_count': 94,
#   'last_containing_document': 1779},
#  "you've": {'total_frequency': 493,
#   'containing_document_count': 363,
#   'last_containing_document': 1781},
#  'smaller': {'total_frequency': 157,
#   'containing_document_count': 129,
#   'last_containing_document': 1780},
#  'monitor': {'total_frequency': 175,
#   'containing_document_count': 109,
#   'last_containing_document': 1729},
#  'than': {'total_frequency': 4900,
#   'containing_document_count': 1102,
#   'last_containing_document': 1784},
#  'luser': {'total_frequency': 35,
#   'containing_document_count': 33,
#   'last_containing_document': 1731},
#  'syndrome': {'total_frequency': 13,
#   'containing_document_count': 11,
#   'last_containing_document': 1702},
#  '19': {'total_frequency': 84,
#   'containing_document_count': 69,
#   'last_containing_document': 1755},
#  'object': {'total_frequency': 2243,
#   'containing_document_count': 567,
#   'last_containing_document': 1784},
#  'resizing': {'total_frequency': 20,
#   'containing_document_count': 16,
#   'last_containing_document': 1718},
#  'recent': {'total_frequency': 562,
#   'containing_document_count': 373,
#   'last_containing_document': 1783},
#  'ash.gnuenterprise.org': {'total_frequency': 25,
#   'containing_document_count': 19,
#   'last_containing_document': 1761},
#  'see': {'total_frequency': 7961,
#   'containing_document_count': 1322,
#   'last_containing_document': 1784},
#  'forms/src/uidrivers/nstti/README': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2},
#  'seems': {'total_frequency': 3042,
#   'containing_document_count': 1086,
#   'last_containing_document': 1784},
#  'possibly': {'total_frequency': 386,
#   'containing_document_count': 286,
#   'last_containing_document': 1781},
#  'snapshot': {'total_frequency': 197,
#   'containing_document_count': 121,
#   'last_containing_document': 1770},
#  'hopefully': {'total_frequency': 398,
#   'containing_document_count': 295,
#   'last_containing_document': 1781},
#  'lupo': {'total_frequency': 392,
#   'containing_document_count': 104,
#   'last_containing_document': 1776},
#  'going': {'total_frequency': 3837,
#   'containing_document_count': 1052,
#   'last_containing_document': 1784},
#  "haven't": {'total_frequency': 1559,
#   'containing_document_count': 771,
#   'last_containing_document': 1784},
#  'check': {'total_frequency': 1859,
#   'containing_document_count': 824,
#   'last_containing_document': 1784},
#  'couple': {'total_frequency': 594,
#   'containing_document_count': 405,
#   'last_containing_document': 1779},
#  'days': {'total_frequency': 1295,
#   'containing_document_count': 691,
#   'last_containing_document': 1783},
#  'archive': {'total_frequency': 150,
#   'containing_document_count': 121,
#   'last_containing_document': 1777},
#  'directly': {'total_frequency': 528,
#   'containing_document_count': 380,
#   'last_containing_document': 1781},
#  'load': {'total_frequency': 812,
#   'containing_document_count': 432,
#   'last_containing_document': 1781},
#  'packaging': {'total_frequency': 368,
#   'containing_document_count': 216,
#   'last_containing_document': 1781},
#  'yep': {'total_frequency': 1710,
#   'containing_document_count': 782,
#   'last_containing_document': 1781},
#  'Its': {'total_frequency': 172,
#   'containing_document_count': 133,
#   'last_containing_document': 1781},
#  'also': {'total_frequency': 3971,
#   'containing_document_count': 1104,
#   'last_containing_document': 1783},
#  'edit': {'total_frequency': 586,
#   'containing_document_count': 317,
#   'last_containing_document': 1779},
#  'connection.conf': {'total_frequency': 68,
#   'containing_document_count': 55,
#   'last_containing_document': 1757},
#  'via': {'total_frequency': 1375,
#   'containing_document_count': 655,
#   'last_containing_document': 1781},
#  'anything': {'total_frequency': 2623,
#   'containing_document_count': 944,
#   'last_containing_document': 1784},
#  'european': {'total_frequency': 68,
#   'containing_document_count': 58,
#   'last_containing_document': 1764},
#  'conference': {'total_frequency': 128,
#   'containing_document_count': 85,
#   'last_containing_document': 1779},
#  'step': {'total_frequency': 512,
#   'containing_document_count': 326,
#   'last_containing_document': 1780},
#  'date': {'total_frequency': 838,
#   'containing_document_count': 424,
#   'last_containing_document': 1784},
#  'simple': {'total_frequency': 1207,
#   'containing_document_count': 607,
#   'last_containing_document': 1781},
#  'measurable': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2},
#  'wrong': {'total_frequency': 1849,
#   'containing_document_count': 827,
#   'last_containing_document': 1784},
#  'damn': {'total_frequency': 1345,
#   'containing_document_count': 626,
#   'last_containing_document': 1781},
#  'kernel': {'total_frequency': 1015,
#   'containing_document_count': 314,
#   'last_containing_document': 1781},
#  'traffic': {'total_frequency': 156,
#   'containing_document_count': 119,
#   'last_containing_document': 1740},
#  'yet': {'total_frequency': 3125,
#   'containing_document_count': 1056,
#   'last_containing_document': 1784},
#  'meeting': {'total_frequency': 447,
#   'containing_document_count': 261,
#   'last_containing_document': 1780},
#  'somewhen': {'total_frequency': 12,
#   'containing_document_count': 12,
#   'last_containing_document': 1738},
#  'year': {'total_frequency': 1117,
#   'containing_document_count': 564,
#   'last_containing_document': 1781},
#  'officially': {'total_frequency': 116,
#   'containing_document_count': 111,
#   'last_containing_document': 1780},
#  'when': {'total_frequency': 7624,
#   'containing_document_count': 1299,
#   'last_containing_document': 1784},
#  'vacations': {'total_frequency': 7,
#   'containing_document_count': 7,
#   'last_containing_document': 1668},
#  'agreed': {'total_frequency': 279,
#   'containing_document_count': 202,
#   'last_containing_document': 1769},
#  'announce': {'total_frequency': 86,
#   'containing_document_count': 67,
#   'last_containing_document': 1766},
#  'early': {'total_frequency': 433,
#   'containing_document_count': 298,
#   'last_containing_document': 1784},
#  'hook': {'total_frequency': 170,
#   'containing_document_count': 131,
#   'last_containing_document': 1716},
#  'developers': {'total_frequency': 883,
#   'containing_document_count': 459,
#   'last_containing_document': 1781},
#  'far': {'total_frequency': 1302,
#   'containing_document_count': 690,
#   'last_containing_document': 1781},
#  'gratis': {'total_frequency': 8,
#   'containing_document_count': 8,
#   'last_containing_document': 1295},
#  'cable': {'total_frequency': 240,
#   'containing_document_count': 126,
#   'last_containing_document': 1781},
#  'modem': {'total_frequency': 272,
#   'containing_document_count': 133,
#   'last_containing_document': 1781},
#  'connection': {'total_frequency': 1100,
#   'containing_document_count': 496,
#   'last_containing_document': 1781},
#  'guy': {'total_frequency': 972,
#   'containing_document_count': 521,
#   'last_containing_document': 1784},
#  "who's": {'total_frequency': 221,
#   'containing_document_count': 192,
#   'last_containing_document': 1781},
#  'interested': {'total_frequency': 679,
#   'containing_document_count': 421,
#   'last_containing_document': 1781},
#  'side': {'total_frequency': 948,
#   'containing_document_count': 525,
#   'last_containing_document': 1779},
#  'planet': {'total_frequency': 60,
#   'containing_document_count': 47,
#   'last_containing_document': 1751},
#  'somehow': {'total_frequency': 366,
#   'containing_document_count': 294,
#   'last_containing_document': 1778},
#  'cloning': {'total_frequency': 10,
#   'containing_document_count': 9,
#   'last_containing_document': 1603},
#  'europe': {'total_frequency': 120,
#   'containing_document_count': 82,
#   'last_containing_document': 1784},
#  'german': {'total_frequency': 263,
#   'containing_document_count': 161,
#   'last_containing_document': 1777},
#  '15:07:03': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2},
#  '15:07:04': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2},
#  '15:07:46': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2},
#  '15:08:03': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2},
#  '15:08:28': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2},
#  '15:09:48': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2},
#  'understood': {'total_frequency': 136,
#   'containing_document_count': 116,
#   'last_containing_document': 1781},
#  'yea': {'total_frequency': 1878,
#   'containing_document_count': 625,
#   'last_containing_document': 1784},
#  'english': {'total_frequency': 424,
#   'containing_document_count': 252,
#   'last_containing_document': 1777},
#  'his': {'total_frequency': 2279,
#   'containing_document_count': 763,
#   'last_containing_document': 1781},
#  'babelfish': {'total_frequency': 10,
#   'containing_document_count': 10,
#   'last_containing_document': 1655},
#  'When': {'total_frequency': 224,
#   'containing_document_count': 172,
#   'last_containing_document': 1781},
#  'gontran': {'total_frequency': 166,
#   'containing_document_count': 26,
#   'last_containing_document': 1777},
#  'note': {'total_frequency': 453,
#   'containing_document_count': 312,
#   'last_containing_document': 1781},
#  'anybody': {'total_frequency': 487,
#   'containing_document_count': 376,
#   'last_containing_document': 1777},
#  'listening': {'total_frequency': 151,
#   'containing_document_count': 121,
#   'last_containing_document': 1767},
#  'redhat7.3': {'total_frequency': 4,
#   'containing_document_count': 3,
#   'last_containing_document': 1084},
#  'python2.2': {'total_frequency': 115,
#   'containing_document_count': 67,
#   'last_containing_document': 1783},
#  'rpm': {'total_frequency': 371,
#   'containing_document_count': 135,
#   'last_containing_document': 1759},
#  'submit': {'total_frequency': 269,
#   'containing_document_count': 176,
#   'last_containing_document': 1780},
#  'bug': {'total_frequency': 2045,
#   'containing_document_count': 732,
#   'last_containing_document': 1781},
#  'spending': {'total_frequency': 77,
#   'containing_document_count': 70,
#   'last_containing_document': 1784},
#  'few': {'total_frequency': 2223,
#   'containing_document_count': 939,
#   'last_containing_document': 1781},
#  'hours': {'total_frequency': 985,
#   'containing_document_count': 548,
#   'last_containing_document': 1784},
#  'refresh': {'total_frequency': 99,
#   'containing_document_count': 66,
#   'last_containing_document': 1757},
#  'narrowing': {'total_frequency': 1,
#   'containing_document_count': 1,
#   'last_containing_document': 2},
#  'down': {'total_frequency': 2184,
#   'containing_document_count': 832,
#   'last_containing_document': 1781},
#  'nstti-0.3': {'total_frequency': 2,
#   'containing_document_count': 2,
#   'last_containing_document': 951},
#  'text': {'total_frequency': 1029,
#   'containing_document_count': 511,
#   'last_containing_document': 1780},
#  'ui': {'total_frequency': 668,
#   'containing_document_count': 292,
#   'last_containing_document': 1780},
#  'better': {'total_frequency': 3497,
#   'containing_document_count': 1026,
#   'last_containing_document': 1784},
#  'worse': {'total_frequency': 313,
#   'containing_document_count': 244,
#   'last_containing_document': 1784},
#  'curses': {'total_frequency': 605,
#   'containing_document_count': 220,
#   'last_containing_document': 1781},
#  'further': {'total_frequency': 280,
#   'containing_document_count': 231,
#   'last_containing_document': 1782},
#  'abstraction': {'total_frequency': 275,
#   'containing_document_count': 140,
#   'last_containing_document': 1784},
#  'tested': {'total_frequency': 437,
#   'containing_document_count': 317,
#   'last_containing_document': 1784},
#  '3.0': {'total_frequency': 116,
#   'containing_document_count': 83,
#   'last_containing_document': 1781},
#  'both': {'total_frequency': 1862,
#   'containing_document_count': 791,
#   'last_containing_document': 1781},
#  'python2.1': {'total_frequency': 141,
#   'containing_document_count': 62,
#   'last_containing_document': 1767},
#  'ummm': {'total_frequency': 208,
#   'containing_document_count': 161,
#   'last_containing_document': 1767},
#  'cause': {'total_frequency': 1334,
#   'containing_document_count': 635,
#   'last_containing_document': 1781},
#  'market': {'total_frequency': 239,
#   'containing_document_count': 153,
#   'last_containing_document': 1776},
#  'share': {'total_frequency': 378,
#   'containing_document_count': 267,
#   'last_containing_document': 1773},
#  'deadcat': {'total_frequency': 14,
#   'containing_document_count': 10,
#   'last_containing_document': 1621},
#  'testing': {'total_frequency': 963,
#   'containing_document_count': 501,
#   'last_containing_document': 1784},
#  'corps': {'total_frequency': 15,
#   'containing_document_count': 14,
#   'last_containing_document': 1623},
#  'since': {'total_frequency': 1818,
#   'containing_document_count': 844,
#   'last_containing_document': 1783},
#  'contracts': {'total_frequency': 38,
#   'containing_document_count': 34,
#   'last_containing_document': 1781},
#  'hmmm': {'total_frequency': 2225,
#   'containing_document_count': 921,
#   'last_containing_document': 1781},
#  'clients': {'total_frequency': 542,
#   'containing_document_count': 292,
#   'last_containing_document': 1781},
#  'special': {'total_frequency': 443,
#   'containing_document_count': 318,
#   'last_containing_document': 1781},
#  "I'd": {'total_frequency': 1516,
#   'containing_document_count': 726,
#   'last_containing_document': 1784},
#  'trouble': {'total_frequency': 357,
#   'containing_document_count': 270,
#   'last_containing_document': 1781},
#  'trying': {'total_frequency': 2718,
#   'containing_document_count': 981,
#   'last_containing_document': 1784},
#  'convince': {'total_frequency': 78,
#   'containing_document_count': 68,
#   'last_containing_document': 1770},
#  'boss': {'total_frequency': 185,
#   'containing_document_count': 127,
#   'last_containing_document': 1779},
#  'bed': {'total_frequency': 659,
#   'containing_document_count': 403,
#   'last_containing_document': 1781},
#  'laters': {'total_frequency': 3,
#   'containing_document_count': 3,
#   'last_containing_document': 514},
#  ...}

# %%
WORD_COUNT
# Out:
# 4311279

# %%
def get_term_frequency(word_frequency_in_document, total_number_of_terms_in_document):
    return word_frequency_in_document / total_number_of_terms_in_document

# %%
def get_inverse_document_frequency(total_number_of_documents, number_of_documents_with_word):
    return math.log(total_number_of_documents, number_of_documents_with_word)
